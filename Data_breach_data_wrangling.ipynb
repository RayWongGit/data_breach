# %% [markdown]
# ## Privacy Rights Clearinghouse Data Breaches Data Wrangling

# %% [markdown]
# ### Loading data

# %%
#import libraries
import pandas as pd
import numpy as np
import datetime as dt
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib

# %%
#load data
df = pd.read_csv('data/Privacy_Rights_Clearinghouse_Data_Breaches_Export.csv', 
                 thousands = ',', parse_dates = ['Date Made Public'], encoding = 'utf-8')
df.head()
# Out:
#   Date Made Public                         Company              City  \
# 0       2009-10-21   Bullitt County Public Schools    Shepherdsville
# 1       2009-10-21  Roane State Community College           Harriman
# 2       2009-10-15                  Halifax Health     Daytona Beach
# 3       2009-10-04       Suffolk Community College            Selden
# 4       2009-09-28                Penrose Hospital  Colorado Springs
#
#        State Type of breach Type of organization  Total Records  \
# 0   Kentucky           DISC                  EDU          676.0
# 1  Tennessee           PORT                  EDU        14783.0
# 2    Florida           PORT                  MED        33000.0
# 3   New York           DISC                  EDU          300.0
# 4   Colorado           PHYS                  MED          175.0
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude
# 0        NaN            2009  37.988399  -85.715792
# 1        NaN            2009  35.933964  -84.552436
# 2        NaN            2009  29.210815  -81.022833
# 3        NaN            2009  40.866487  -73.035663
# 4        NaN            2009  38.833882 -104.821363

# %% [markdown]
# ### Assessing data

# %%
#create a subset exclude data breaches in year 2018
df = df[df['Year of Breach'] != 2018]

# %%
# double check number of records of year 2018
sum(df['Year of Breach'] == 2018)
# Out:
# 0

# %%
# check the basic info. of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7925 entries, 0 to 8512
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date Made Public         7925 non-null   datetime64[ns]
#  1   Company                  7925 non-null   object
#  2   City                     5492 non-null   object
#  3   State                    7827 non-null   object
#  4   Type of breach           7925 non-null   object
#  5   Type of organization     7925 non-null   object
#  6   Total Records            7925 non-null   float64
#  7   Description of incident  7922 non-null   object
#  8   Information Source       7871 non-null   object
#  9   Source URL               2698 non-null   object
#  10  Year of Breach           7925 non-null   int64
#  11  Latitude                 7925 non-null   float64
#  12  Longitude                7925 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 866.8+ KB

# %% [markdown]
# - Some columns have missing values
# - The data type of 'Total Records' column is float, while it should be int

# %%
# check missing values by variables
df.isnull().sum()
# Out:
# Date Made Public              0
# Company                       0
# City                       2433
# State                        98
# Type of breach                0
# Type of organization          0
# Total Records                 0
# Description of incident       3
# Information Source           54
# Source URL                 5227
# Year of Breach                0
# Latitude                      0
# Longitude                     0
# dtype: int64

# %% [markdown]
# Variable 'City', 'State', 'Total Records', 'Description of incident', 'Information Source' and 'Source URL' have missing values.

# %%
# check duplicates
df.duplicated().sum()
# Out:
# 13

# %% [markdown]
# There are 13 duplicated records

# %%
# description of the dataset
df.describe()
# Out:
#        Total Records  Year of Breach     Latitude    Longitude
# count   7.925000e+03     7925.000000  7925.000000  7925.000000
# mean    1.279903e+06     2012.197603    38.285108   -88.387036
# std     4.013869e+07        3.217321     5.337308    19.252870
# min     0.000000e+00     2006.000000   -34.603684  -158.056892
# 25%     0.000000e+00     2010.000000    35.960638   -97.133068
# 50%     8.620000e+02     2012.000000    39.961176   -82.465144
# 75%     5.220000e+03     2015.000000    40.760537   -73.978890
# max     3.000000e+09     2017.000000    64.837778   139.691706

# %%
df['Type of breach'].value_counts()
# Out:
# HACK    2329
# PHYS    1661
# DISC    1613
# PORT    1134
# INSD     594
# UNKN     287
# STAT     239
# CARD      68
# Name: Type of breach, dtype: int64

# %%
df['Type of organization'].value_counts()
# Out:
# MED     3952
# BSO     1022
# EDU      757
# GOV      755
# BSF      710
# BSR      579
# NGO      114
# UNKN      36
# Name: Type of organization, dtype: int64

# %% [markdown]
# Based on the exploration above, the dataset has problems below:
# - Variable 'City', 'State', 'Description of incident', 'Information Source' and 'Source URL' have missing values.
# - The data type of 'Total Records' column is float, while it should be int
# - There are 13 duplicated records
# - There are 226 records with value of 'UNKN' in 'Type of breach' column, 36 in column 'Type of organization', we will exclude these.
#
# We will clean the data in the next part

# %% [markdown]
# ### Cleaning data

# %% [markdown]
# #### Filling missing values in 'State' column

# %%
# missing values in State
df[df.State.isnull()]
# Out:
#      Date Made Public                                            Company  \
# 373        2007-09-12                      TennCare, Americhoice Inc.
# 697        2009-01-27                                     U.S. Consulate
# 947        2006-02-23                          Deloitte & Touche, McAfee
# 1112       2009-12-04                        Eastern Illinois University
# 1306       2008-04-17  SunGard, Connecticut State University System, ...
# ...               ...                                                ...
# 8484       2018-10-22                                   Byram healthcare
# 8493       2018-10-16         Chicago property managementand investments
# 8495       2018-10-12                           Buehlers fresh foods llc
# 8506       2018-10-08                                    Trans union llc
# 8512       2018-10-04                      Professional publications inc
#
#            City State Type of breach Type of organization  Total Records  \
# 373   Knoxville   NaN           PORT                  MED        67000.0
# 697         NaN   NaN           PHYS                  GOV            0.0
# 947         NaN   NaN           PORT                  BSO         9290.0
# 1112        NaN   NaN           HACK                  EDU         9000.0
# 1306        NaN   NaN           PORT                  BSO            0.0
# ...         ...   ...            ...                  ...            ...
# 8484        NaN   NaN           UNKN                 UNKN           52.0
# 8493        NaN   NaN           UNKN                 UNKN           79.0
# 8495        NaN   NaN           UNKN                 UNKN         2040.0
# 8506        NaN   NaN           UNKN                 UNKN          242.0
# 8512        NaN   NaN           UNKN                 UNKN         1162.0
#
#                                 Description of incident  \
# 373   There are 67,000 TennCare \n            enroll...
# 697   Hundreds of files - with Social Security numbe...
# 947   An external auditor lost a CD with names, Soci...
# 1112  A computer was compromised by a virus. That ca...
# 1306  At least 18 colleges are scrambling to inform ...
# ...                                                 ...
# 8484  Information on this security breach is provide...
# 8493  Information on this security breach is provide...
# 8495  Information on this security breach is provide...
# 8506  Information on this security breach is provide...
# 8512  Information on this security breach is provide...
#
#             Information Source                                   Source URL  \
# 373                Dataloss DB                                          NaN
# 697                      Media                                          NaN
# 947                        NaN                                          NaN
# 1112                       NaN                                          NaN
# 1306                       NaN                                          NaN
# ...                        ...                                          ...
# 8484  Indiana Attorney General  https://www.in.gov/attorneygeneral/2874.htm
# 8493  Indiana Attorney General  https://www.in.gov/attorneygeneral/2874.htm
# 8495  Indiana Attorney General  https://www.in.gov/attorneygeneral/2874.htm
# 8506  Indiana Attorney General  https://www.in.gov/attorneygeneral/2874.htm
# 8512  Indiana Attorney General  https://www.in.gov/attorneygeneral/2874.htm
#
#       Year of Breach   Latitude  Longitude
# 373             2007  35.960638 -83.920739
# 697             2009  37.090240 -95.712891
# 947             2006  37.090240 -95.712891
# 1112            2009  37.090240 -95.712891
# 1306            2008  37.090240 -95.712891
# ...              ...        ...        ...
# 8484            2016  37.090240 -95.712891
# 8493            2017  37.090240 -95.712891
# 8495            2016  37.090240 -95.712891
# 8506            2017  37.090240 -95.712891
# 8512            2017  37.090240 -95.712891
#
# [98 rows x 13 columns]

# %% [markdown]
# From the values of City or Latitude and Longitude, we are able to identify the names of the states and fill in the missing values.

# %%
# fill in the missing values of state
df.loc[373, 'State'] = 'TN'
df.loc[697, 'State'] = 'Non-US'
df.loc[947, 'State'] = 'CA'
df.loc[1112, 'State'] = 'IL'
df.loc[1306, 'State'] = 'CT'
df.loc[1767, 'State'] = 'NY'
df.loc[1798, 'State'] = 'KS'
df.loc[1804, 'State'] = 'KS'
df.loc[1853, 'State'] = 'New Hampshire'
df.loc[2173, 'State'] = 'New Jersey'
df.loc[2244, 'State'] = 'CA'
df.loc[2257, 'State'] = 'KS'
df.loc[2259, 'State'] = 'AZ'
df.loc[2266, 'State'] = 'IL'
df.loc[2278, 'State'] = 'AL'
df.loc[2279, 'State'] = 'OH'
df.loc[2284, 'State'] = 'MA'
df.loc[2289, 'State'] = 'NY'
df.loc[2491, 'State'] = 'VA'
df.loc[2501, 'State'] = 'KS'
df.loc[2588, 'State'] = 'GA'
df.loc[2622, 'State'] = 'TX'
df.loc[2623, 'State'] = 'TN'
df.loc[2820, 'State'] = 'MA'
df.loc[2988, 'State'] = 'Germany'
df.loc[3014, 'State'] = 'FL'
df.loc[3081, 'State'] = 'Minnesota'
df.loc[3558, 'State'] = 'Oregon'
df.loc[3321, 'State'] = 'OH'
df.loc[3377, 'State'] = 'CA'
df.loc[3573, 'State'] = 'FL'
df.loc[3580, 'State'] = 'VA'
df.loc[3595, 'State'] = 'NC'
df.loc[3857, 'State'] = 'KS'
df.loc[3866, 'State'] = 'Virginia'
df.loc[3969, 'State'] = 'CA'
df.loc[4055, 'State'] = 'Texas'
df.loc[4079, 'State'] = 'KS'
df.loc[4430, 'State'] = 'CA'
df.loc[4430, 'City'] = 'Los Angeles'
df.loc[4507, 'State'] = 'NY'
df.loc[4577, 'State'] = 'MI'
df.loc[4844, 'State'] = 'PA'
df.loc[4855, 'State'] = 'TX'
df.loc[5364, 'State'] = 'NY'
df.loc[5422, 'State'] = 'PR'
df.loc[5433, 'State'] = 'PR'
df.loc[5443, 'State'] = 'PR'
df.loc[5483, 'State'] = 'PR'
df.loc[5603, 'State'] = 'MA'
df.loc[6148, 'State'] = 'PR'
df.loc[6220, 'State'] = 'PR'
df.loc[6289, 'State'] = 'PR'
df.loc[6289, 'State'] = 'PR'
df.loc[6500, 'State'] = 'PR'
df.loc[7143, 'State'] = 'TX'
df.loc[7527, 'State'] = 'Switzerland'
df.loc[7635, 'State'] = 'Hong Kong'
df.loc[7727, 'State'] = 'CA'
df.loc[7731, 'State'] = 'TX'
df.loc[7732, 'State'] = 'VA'
df.loc[7916, 'State'] = 'MN'
df.loc[7978, 'State'] = 'IL'
df.loc[8178, 'State'] = 'MT'
df.loc[8279, 'State'] = 'TX'
df.loc[8301, 'State'] = 'OK'
df.loc[8405, 'State'] = 'CA'
df.loc[8406, 'State'] = 'CA'
df.loc[8493, 'State'] = 'IL'
df.loc[8183, 'State'] = 'NY'
df.loc[8195, 'State'] = 'IN'
df.loc[8240, 'State'] = 'IL'
df.loc[8245, 'State'] = 'PA'
df.loc[8257, 'State'] = 'OH'
df.loc[8275, 'State'] = 'RI'
df.loc[8281, 'State'] = 'FL'
df.loc[8298, 'State'] = 'CA'
df.loc[8309, 'State'] = 'England'
df.loc[8352, 'State'] = 'MN'
df.loc[8358, 'State'] = 'IL'
df.loc[8363, 'State'] = 'CA'
df.loc[8366, 'State'] = 'VA'
df.loc[8483, 'State'] = 'IL'
df.loc[8506, 'State'] = 'IL'
df.loc[8367, 'State'] = 'FL'
df.loc[8429, 'State'] = 'TX'
df.loc[8432, 'State'] = 'NY'
df.loc[8440, 'State'] = 'FL'
df.loc[8452, 'State'] = 'KY'
df.loc[8495, 'State'] = 'OH'
df.loc[8512, 'State'] = 'CA'
df.loc[8173, 'State'] = 'IN'
df.loc[8300, 'State'] = 'IN'
df.loc[8310, 'State'] = 'IN'
df.loc[8313, 'State'] = 'IN'
df.loc[8351, 'State'] = 'CA'
df.loc[8359, 'State'] = 'CA'
df.loc[8398, 'State'] = 'CA'
df.loc[8456, 'State'] = 'IN'
df.loc[8476, 'State'] = 'IN'
df.loc[8484, 'State'] = 'IN'

# %%
# missing values in State after modified
df[df.State.isnull()]
# Out:
# Empty DataFrame
# Columns: [Date Made Public, Company, City, State, Type of breach, Type of organization, Total Records, Description of incident, Information Source, Source URL, Year of Breach, Latitude, Longitude]
# Index: []

# %%
df.State.isnull().sum()
# Out:
# 0

# %% [markdown]
# There are no missing values in 'State' column now.

# %%
# total obs by state
df['State'].value_counts()
# Out:
# California     1214
# New York        590
# Texas           544
# Florida         427
# Maryland        345
#                ...
# AL                1
# Switzerland       1
# GA                1
# Berlin            1
# NC                1
# Name: State, Length: 94, dtype: int64

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
#replace the state abbreviations with full names
df.State.replace(states, inplace = True)

# %%
df.State.value_counts()
# Out:
# California       1228
# New York          596
# Texas             550
# Florida           432
# Maryland          345
#                  ...
# Grand Bahama        1
# Beijing             1
# Berlin              1
# Noord Holland       1
# Tokyo               1
# Name: State, Length: 70, dtype: int64

# %% [markdown]
# #### Droping duplicates

# %%
# check the duplicated obs.
df[df.duplicated(keep = False)].sort_values(by = 'Date Made Public', ascending = False)
# Out:
#      Date Made Public                                            Company  \
# 7689       2017-12-08                         Mount Carmel Health System
# 7683       2017-12-08                         Mount Carmel Health System
# 7692       2017-12-05              Oklahoma Department of Human Services
# 7691       2017-12-05                           Bronson Healthcare Group
# 7685       2017-12-05              Oklahoma Department of Human Services
# 7684       2017-12-05                           Bronson Healthcare Group
# 7695       2017-12-01                             CCRM Minneapolis, P.C.
# 7694       2017-12-01                    Washington Health System Greene
# 7693       2017-12-01                               Sinai Health System
# 7688       2017-12-01                             CCRM Minneapolis, P.C.
# 7687       2017-12-01                    Washington Health System Greene
# 7686       2017-12-01                               Sinai Health System
# 7130       2017-05-30  N. Fred Eaglstein, D.O. d/b/a Dermatology and ...
# 7114       2017-05-30  N. Fred Eaglstein, D.O. d/b/a Dermatology and ...
# 7125       2017-05-26                   Mississippi Division of Medicaid
# 7113       2017-05-26                   Mississippi Division of Medicaid
# 7122       2017-05-19                          Children's Mercy Hospital
# 7111       2017-05-19                          Children's Mercy Hospital
# 7121       2017-05-18  Neeley-Nemeth, LLP d/b/a Barton Oaks Dental Group
# 7120       2017-05-18        Kennewick General Hospital dba Trios Health
# 7110       2017-05-18  Neeley-Nemeth, LLP d/b/a Barton Oaks Dental Group
# 7109       2017-05-18        Kennewick General Hospital dba Trios Health
# 3623       2013-07-24                                             Tinder
# 3622       2013-07-24                                             Tinder
# 3580       2013-06-12                                           comScore
# 3579       2013-06-12                                           comScore
# 2687       2012-02-21                             Ochsner Medical Center
# 2686       2012-02-21                             Ochsner Medical Center
#
#                 City         State Type of breach Type of organization  \
# 7689             NaN          Ohio           DISC                  MED
# 7683             NaN          Ohio           DISC                  MED
# 7692             NaN      Oklahoma           HACK                  MED
# 7691             NaN      Michigan           HACK                  MED
# 7685             NaN      Oklahoma           HACK                  MED
# 7684             NaN      Michigan           HACK                  MED
# 7695             NaN     Minnesota           HACK                  MED
# 7694             NaN  Pennsylvania           PHYS                  MED
# 7693             NaN      Illinois           HACK                  MED
# 7688             NaN     Minnesota           HACK                  MED
# 7687             NaN  Pennsylvania           PHYS                  MED
# 7686             NaN      Illinois           HACK                  MED
# 7130             NaN       Florida           DISC                  MED
# 7114             NaN       Florida           DISC                  MED
# 7125             NaN   Mississippi           DISC                  MED
# 7113             NaN   Mississippi           DISC                  MED
# 7122             NaN      Missouri           DISC                  MED
# 7111             NaN      Missouri           DISC                  MED
# 7121             NaN         Texas           HACK                  MED
# 7120             NaN    Washington           DISC                  MED
# 7110             NaN         Texas           HACK                  MED
# 7109             NaN    Washington           DISC                  MED
# 3623  West Hollywood    California           DISC                  BSO
# 3622  West Hollywood    California           DISC                  BSO
# 3580          Reston      Virginia           DISC                  BSR
# 3579          Reston      Virginia           DISC                  BSR
# 2687     New Orleans     Louisiana           PORT                  MED
# 2686     New Orleans     Louisiana           PORT                  MED
#
#       Total Records                            Description of incident  \
# 7689          836.0  Location of breached information: Email\nBusin...
# 7683          836.0  Location of breached information: Email\nBusin...
# 7692        47000.0  Location of breached information: Network Serv...
# 7691         8256.0  Location of breached information: Email\nBusin...
# 7685        47000.0  Location of breached information: Network Serv...
# 7684         8256.0  Location of breached information: Email\nBusin...
# 7695         3280.0  Location of breached information: Network Serv...
# 7694         4145.0  Location of breached information: Other Portab...
# 7693        11347.0  Location of breached information: Email\nBusin...
# 7688         3280.0  Location of breached information: Network Serv...
# 7687         4145.0  Location of breached information: Other Portab...
# 7686        11347.0  Location of breached information: Email\nBusin...
# 7130         2000.0  Location of breached information: Electronic M...
# 7114         2000.0  Location of breached information: Electronic M...
# 7125         5220.0  Location of breached information: Email\nBusin...
# 7113         5220.0  Location of breached information: Email\nBusin...
# 7122         5511.0  Location of breached information: Other\nBusin...
# 7111         5511.0  Location of breached information: Other\nBusin...
# 7121        17090.0  Location of breached information: Desktop Comp...
# 7120          569.0  Location of breached information: Electronic M...
# 7110        17090.0  Location of breached information: Desktop Comp...
# 7109          569.0  Location of breached information: Electronic M...
# 3623            0.0  Tinder advertises to users that their physical...
# 3622            0.0  Tinder advertises to users that their physical...
# 3580            0.0  Two comScore panelists filed a lawsuit in Augu...
# 3579            0.0  Two comScore panelists filed a lawsuit in Augu...
# 2687            0.0  A hard drive was discovered missing on Februar...
# 2686            0.0  A hard drive was discovered missing on Februar...
#
#                               Information Source  \
# 7689  US Department of Health and Human Services
# 7683  US Department of Health and Human Services
# 7692  US Department of Health and Human Services
# 7691  US Department of Health and Human Services
# 7685  US Department of Health and Human Services
# 7684  US Department of Health and Human Services
# 7695  US Department of Health and Human Services
# 7694  US Department of Health and Human Services
# 7693  US Department of Health and Human Services
# 7688  US Department of Health and Human Services
# 7687  US Department of Health and Human Services
# 7686  US Department of Health and Human Services
# 7130  US Department of Health and Human Services
# 7114  US Department of Health and Human Services
# 7125  US Department of Health and Human Services
# 7113  US Department of Health and Human Services
# 7122  US Department of Health and Human Services
# 7111  US Department of Health and Human Services
# 7121  US Department of Health and Human Services
# 7120  US Department of Health and Human Services
# 7110  US Department of Health and Human Services
# 7109  US Department of Health and Human Services
# 3623                                       Media
# 3622                                       Media
# 3580                                       Media
# 3579                                       Media
# 2687                              PHIPrivacy.net
# 2686                              PHIPrivacy.net
#
#                                              Source URL  Year of Breach  \
# 7689  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7683  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7692  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7691  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7685  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7684  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7695  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7694  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7693  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7688  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7687  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7686  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7130  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7114  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7125  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7113  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7122  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7111  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7121  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7120  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7110  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 7109  https://ocrportal.hhs.gov/ocr/breach/breach_re...            2017
# 3623                                                NaN            2013
# 3622                                                NaN            2013
# 3580                                                NaN            2013
# 3579                                                NaN            2013
# 2687                                                NaN            2012
# 2686                                                NaN            2012
#
#        Latitude   Longitude
# 7689  37.090240  -95.712891
# 7683  37.090240  -95.712891
# 7692  37.090240  -95.712891
# 7691  37.090240  -95.712891
# 7685  37.090240  -95.712891
# 7684  37.090240  -95.712891
# 7695  37.090240  -95.712891
# 7694  37.090240  -95.712891
# 7693  37.090240  -95.712891
# 7688  37.090240  -95.712891
# 7687  37.090240  -95.712891
# 7686  37.090240  -95.712891
# 7130  27.664827  -81.515754
# 7114  27.664827  -81.515754
# 7125  32.354668  -89.398528
# 7113  32.354668  -89.398528
# 7122  37.964253  -91.831833
# 7111  37.964253  -91.831833
# 7121  31.968599  -99.901813
# 7120  47.751074 -120.740139
# 7110  31.968599  -99.901813
# 7109  47.751074 -120.740139
# 3623  34.090009 -118.361744
# 3622  34.090009 -118.361744
# 3580  38.958631  -77.357003
# 3579  38.958631  -77.357003
# 2687  29.951066  -90.071532
# 2686  29.951066  -90.071532

# %%
#drop the duplicated obs.
df.drop_duplicates(keep = 'first', inplace = True)

# %%
# pd.set_option('max_colwidth', 400)
df[df.State.isnull()]['Description of incident']
# Out:
# Series([], Name: Description of incident, dtype: object)

# %%
#missing value after modification
df.isnull().sum()
# Out:
# Date Made Public              0
# Company                       0
# City                       2422
# State                         0
# Type of breach                0
# Type of organization          0
# Total Records                 0
# Description of incident       3
# Information Source           54
# Source URL                 5224
# Year of Breach                0
# Latitude                      0
# Longitude                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# missing values of 'Source URL' by state after modification 
df[df['Source URL'].isnull()]['State'].value_counts().head(5)
# Out:
# California    894
# New York      443
# Texas         348
# Florida       280
# Illinois      203
# Name: State, dtype: int64

# %% [markdown]
# #### Changing data types of column 'Total Records'

# %%
# Changing data type of column 'Total Records' from float to int
df["Total Records"] = df["Total Records"].astype(int)
df["Total Records"].dtype
# Out:
# dtype('int64')

# %%
# value counts of total records
df["Total Records"].value_counts()
# Out:
# 0        2187
# 500        86
# 1000       78
# 2000       78
# 3000       55
#          ...
# 4469        1
# 10172       1
# 1237        1
# 5335        1
# 32842       1
# Name: Total Records, Length: 2434, dtype: int64

# %% [markdown]
# 2187 rows have 0 total records. We need to drop that.

# %% [markdown]
# #### dropping the '0' values in  'Total Records'

# %%
# drop the '0' values in  'Total Records'
df = df[df['Total Records'] != 0]
df["Total Records"].value_counts()
# Out:
# 500     86
# 2000    78
# 1000    78
# 3000    55
# 100     47
#         ..
# 8275     1
# 3560     1
# 7666     1
# 263      1
# 2123     1
# Name: Total Records, Length: 2433, dtype: int64

# %% [markdown]
# #### dropping the 'City' column

# %%
# drop the 'City' column

df.drop('City', axis=1, inplace=True)
df.head()
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude
# 0        NaN            2009  37.988399  -85.715792
# 1        NaN            2009  35.933964  -84.552436
# 2        NaN            2009  29.210815  -81.022833
# 3        NaN            2009  40.866487  -73.035663
# 4        NaN            2009  38.833882 -104.821363

# %% [markdown]
# #### exclude the unkowns

# %%
# exclude the records with 'UNKN' values
df = df[df['Type of breach'] != 'UNKN']
df['Type of organization'].value_counts()
# Out:
# MED    3365
# EDU     568
# GOV     523
# BSO     392
# BSF     327
# BSR     255
# NGO      68
# Name: Type of organization, dtype: int64

# %% [markdown]
# ### Feature engineering
#
# Based on the current columns, we will create some new columns for the purpose of exploration.

# %% [markdown]
# #### breach_type_gA, breach_type_gB, breach_type_gC, breach_type_gD

# %%
df['Type of breach'].value_counts()
# Out:
# PHYS    1397
# HACK    1388
# DISC    1301
# PORT     841
# INSD     364
# STAT     175
# CARD      32
# Name: Type of breach, dtype: int64

# %%
# create a breach type group called breach_type_gA to re-categorize the 
# types of breaches by 'Hacker', 'Others', 'Unknown'
# 'Hacker' correspond to the type of breach 'HACK’ 
# 'Unknown' correspond to the type of breach'Unknown'
# And 'Others' include all the rest types
df['breach_type_gA'] = 'Others'
df.loc[df['Type of breach'] == 'HACK', 'breach_type_gA'] = 'Hacker'
df.loc[df['Type of breach'] == 'UNKN', 'breach_type_gA'] = 'Unknown'

# %%
# create breach type group called breach_type_gB to re-categorize the 
# types of breaches by 'Outsider', 'Insider', 'Mixed', and 'Unknown'.
# 'Outsider' includes the original type of breach 'HACK' and 'CARD'
# 'Insider' includes the original type of breach 'INSD' and 'DISC'
# 'Unknown' right as the original type of breach 'Unknown' 
# 'Mixed' includes all the rest types of breach for which we could not say for
#  sure whether it is outsider or insider since it depends on each specific event
df['breach_type_gB'] = 'Mixed'
df.loc[df['Type of breach'] == 'HACK', 'breach_type_gB'] = 'Outsider'
df.loc[df['Type of breach'] == 'CARD', 'breach_type_gB'] = 'Outsider'
df.loc[df['Type of breach'] == 'INSD', 'breach_type_gB'] = 'Insider'
df.loc[df['Type of breach'] == 'DISC', 'breach_type_gB'] = 'Insider'
df.loc[df['Type of breach'] == 'UNKN', 'breach_type_gB'] = 'Unknown'

# %%
# created a breach type group called 'breach_type_gC' to re-categorize the 
# types of breaches by 'Online', 'Offline', 'Others', 'Unknown', 
# 'Online' includes the type of breach 'CARD’ and'HACK',
# 'Offline' includes the type of breach 'PHYS' and 'PORT'. 
# 'Unknown' correspond to the type of breach'UNKN'. 
# And 'Others' include all the rest types which cover both online and offline

df['breach_type_gC'] = 'Others'
df.loc[df['Type of breach'].isin(['PHYS','PORT']), 'breach_type_gC'] = 'Offline'
df.loc[df['Type of breach'].isin(['CARD', 'HACK']), 'breach_type_gC'] = 'Online'
df.loc[df['Type of breach'] == 'UNKN', 'breach_type_gC'] = 'Unknown'

# %%
# created a breach type group called 'breach_type_gD' to re-categorize the 
# types of breaches by 'Network', 'Local', 'Others', 'Unknown', 
# 'Network' includes the type of breach 'CARD’ and'HACK',
# 'Local' includes the type of breach 'PHYS', 'PORT' and 'STAT'. 
# 'Unknown' correspond to the type of breach'UNKN'. 
# And 'Others' include all the rest types which cover both network and local

df['breach_type_gD'] = 'Others'
df.loc[df['Type of breach'].isin(['PHYS','PORT', 'STAT']), 'breach_type_gD'] = 'Local'
df.loc[df['Type of breach'].isin(['CARD', 'HACK', 'DISC']), 'breach_type_gD'] = 'Network'

# %%
# check the new columns
df.head()
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude breach_type_gA  \
# 0        NaN            2009  37.988399  -85.715792         Others
# 1        NaN            2009  35.933964  -84.552436         Others
# 2        NaN            2009  29.210815  -81.022833         Others
# 3        NaN            2009  40.866487  -73.035663         Others
# 4        NaN            2009  38.833882 -104.821363         Others
#
#   breach_type_gB breach_type_gC breach_type_gD
# 0        Insider         Others        Network
# 1          Mixed        Offline          Local
# 2          Mixed        Offline          Local
# 3        Insider         Others        Network
# 4          Mixed        Offline          Local

# %%
# value counts of each category in 'breach_type_gA'
df['breach_type_gA'].value_counts()
# Out:
# Others    4110
# Hacker    1388
# Name: breach_type_gA, dtype: int64

# %%
# value counts of each category in 'breach_type_gB'
df['breach_type_gB'].value_counts()
# Out:
# Mixed       2413
# Insider     1665
# Outsider    1420
# Name: breach_type_gB, dtype: int64

# %%
# value counts of each category in 'breach_type_gC'
df['breach_type_gC'].value_counts()
# Out:
# Offline    2238
# Others     1840
# Online     1420
# Name: breach_type_gC, dtype: int64

# %%
# value counts of each category in 'breach_type_gD'
df['breach_type_gD'].value_counts()
# Out:
# Network    2721
# Local      2413
# Others      364
# Name: breach_type_gD, dtype: int64

# %% [markdown]
# #### region-A and region-B

# %%
# create a new variable 'region-A' from ‘State’,with the values‘Northeast’, ‘Midwest’,
#‘South’, ‘West’ and 'Non_US' for locations in other countries rather than US.
NE = [ 'Maine', 'New York', 'New Jersey', 'Vermont', 'Massachusetts', 
    'Rhode Island','Connecticut', 'New Hampshire',
             'Pennsylvania']
MW = ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 
           'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin']
S = ['Delaware', 'Florida', 'Georgia', 'Maryland', 'North Carolina', 'South Carolina',
         'Virginia', 'District of Columbia', 'West Virginia', 'Alabama', 'Kentucky', 
         'Mississippi', 'Tennessee', 'Arkansas', 'Louisiana', 'Oklahoma', 'Texas']
W = ['Arizona', 'Colorado', 'Idaho', 'Montana', 'Nevada', 'New Mexico', 'Utah', 'Wyoming', 
        'Alaska', 'California', 'Hawaii', 'Oregon', 'Washington']
df['region_A'] = 'Non_US'
df.loc[df.State.isin(NE), 'region_A'] = 'Northeast'
df.loc[df.State.isin(MW), 'region_A'] = 'Midwest'
df.loc[df.State.isin(S), 'region_A'] = 'South'
df.loc[df.State.isin(W), 'region_A'] = 'West'

# %%
# number of states in each region in US
len(NE), len(MW), len(S), len(W)
# Out:
# (9, 12, 17, 13)

# %%
# create a new variable 'region-B' from 'State',with the values‘Northeast’, ‘Midwest’,
#‘Southeast’, 'Southwest', ‘West’ and 'Non_US' for locations in other countries rather than US.
Northeast = [ 'Maine', 'New York', 'New Jersey', 'Vermont', 'Massachusetts', 
    'Rhode Island','Connecticut', 'New Hampshire',
             'Pennsylvania', 'Delaware', 'Maryland']
Midwest = ['Illinois', 'Indiana', 'Iowa', 'Kansas', 'Michigan', 'Minnesota', 
           'Missouri', 'Nebraska', 'North Dakota', 'Ohio', 'South Dakota', 'Wisconsin']
Southwest = ['Texas', 'Oklahoma', 'New Mexico', 'Arizona']
Southeast = ['Florida', 'Georgia', 'North Carolina', 'South Carolina',
         'Virginia', 'West Virginia', 'Alabama', 'Kentucky', 
         'Mississippi', 'Tennessee', 'Arkansas', 'Louisiana']
West = ['Colorado', 'Idaho', 'Montana', 'Nevada', 'Utah', 'Wyoming', 
        'Alaska', 'California', 'Hawaii', 'Oregon', 'Washington']
df['region_B'] = 'Non_US'
df.loc[df.State.isin(Northeast), 'region_B'] = 'Northeast'
df.loc[df.State.isin(Midwest), 'region_B'] = 'Midwest'
df.loc[df.State.isin(Southwest), 'region_B'] = 'Southwest'
df.loc[df.State.isin(Southeast), 'region_B'] = 'Southeast'
df.loc[df.State.isin(West), 'region_B'] = 'West'

# %%
# number of states in each region in US
len(Northeast), len(Midwest),len(Southwest), len(Southeast), len(West)
# Out:
# (11, 12, 4, 12, 11)

# %%
df.head()
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude breach_type_gA  \
# 0        NaN            2009  37.988399  -85.715792         Others
# 1        NaN            2009  35.933964  -84.552436         Others
# 2        NaN            2009  29.210815  -81.022833         Others
# 3        NaN            2009  40.866487  -73.035663         Others
# 4        NaN            2009  38.833882 -104.821363         Others
#
#   breach_type_gB breach_type_gC breach_type_gD   region_A   region_B
# 0        Insider         Others        Network      South  Southeast
# 1          Mixed        Offline          Local      South  Southeast
# 2          Mixed        Offline          Local      South  Southeast
# 3        Insider         Others        Network  Northeast  Northeast
# 4          Mixed        Offline          Local       West       West

# %%
# value counts
df.region_A.value_counts()
# Out:
# South        1956
# West         1283
# Midwest      1086
# Northeast    1030
# Non_US        143
# Name: region_A, dtype: int64

# %%
# value counts
df.region_B.value_counts()
# Out:
# Northeast    1315
# Southeast    1226
# West         1149
# Midwest      1086
# Southwest     579
# Non_US        143
# Name: region_B, dtype: int64

# %% [markdown]
# #### Age of Law

# %%
# create a new variable called 'Age of Law' to describe how many years a state have had a law 
# regarding the data breach
dict_law = {'California':16, 'Oregon':12, 'Wisconsin':13, 'Florida':14, 'Maryland':11, 
            'Texas':10, 'Virginia':11, 'Georgia':14, 'New Jersey':13, 'New York':14,
            'Massachusetts':12, 'Indiana':13, 'Washington':14, 'Minnesota':13, 'Nevada':14,
            'Pennsylvania':13, 'North Carolina':14, 'South Carolina':10, 'Nebraska':13, 
            'Kansas':13, 'Illinois':13, 'Missouri':10, 'Tennessee':14, 'Maine':13, 'Arizona':13, 
            'Colorado':13, 'Delaware':14, 'Utah':12, 'Connecticut':13,'Ohio':13, 'Kentucky':0, 
            'New Hampshire':12, 'Oklahoma':13, 'Arkansas':14, 'Iowa':11, 'Michigan':12, 'New Mexico':0,
            'Alaska':10, 'North Dakota':14, 'Louisiana':13, 'Idaho':13, 'Vermont':12, 'Rhode Island':13, 
            'Mississippi':8, 'Hawaii':12, 'Alabama':0, 'West Virginia':11, 'Montana':13, 'Wyoming':12,
            'South Dakota':0, 'District Of Columbia':12, 'District Of Columbia':0}
df['age_of_Law'] = df['State'].replace(dict_law, inplace = False)
df.head()
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude breach_type_gA  \
# 0        NaN            2009  37.988399  -85.715792         Others
# 1        NaN            2009  35.933964  -84.552436         Others
# 2        NaN            2009  29.210815  -81.022833         Others
# 3        NaN            2009  40.866487  -73.035663         Others
# 4        NaN            2009  38.833882 -104.821363         Others
#
#   breach_type_gB breach_type_gC breach_type_gD   region_A   region_B  \
# 0        Insider         Others        Network      South  Southeast
# 1          Mixed        Offline          Local      South  Southeast
# 2          Mixed        Offline          Local      South  Southeast
# 3        Insider         Others        Network  Northeast  Northeast
# 4          Mixed        Offline          Local       West       West
#
#   age_of_Law
# 0          0
# 1         14
# 2         14
# 3         14
# 4         13

# %%
# value counts
df.age_of_Law.value_counts()
# Out:
# 13                  1586
# 14                  1391
# 16                   657
# 10                   573
# 11                   469
# 12                   457
# 0                    290
# Puerto Rico           38
# 8                     26
# Quebec                 2
# Ontario                2
# Guangdong              1
# Beijing                1
# British Columbia       1
# London                 1
# Noord Holland          1
# Berlin                 1
# Germany                1
# Name: age_of_Law, dtype: int64

# %% [markdown]
# #### Org_group

# %%
# create a new variable 'Org_group', assign value 'F_regulated' to 'Org_group' where the type of organization is 
# 'EDU'/'MED'/'BSF', for other types of organization assign value 'non_regulated'
df['org_group'] = 'non_F_regulated'
regulated_org = ['EDU', 'MED', 'BSF']
df.loc[df['Type of organization'].isin(regulated_org), 'org_group'] = 'F_regulated'

# %% [markdown]
# #### records_group

# %%
df['Total Records'].value_counts()
# Out:
# 2000      77
# 1000      75
# 500       74
# 3000      54
# 5000      45
#           ..
# 846        1
# 2036       1
# 177000     1
# 327        1
# 2123       1
# Name: Total Records, Length: 2363, dtype: int64

# %%
# there are 3 incidents with the total number of record of more than 1 billion,
# we categorize those 3 obs. as extraordinary, other obs. wil be noted as Others 
df.sort_values('Total Records', ascending = False)
# Out:
#      Date Made Public                                      Company  \
# 5066       2016-12-14                                        Yahoo
# 5171       2017-03-08                             River City Media
# 4207       2014-08-05  Russian hacking discovered by Hold Security
# 4944       2016-09-22                                        Yahoo
# 5029       2016-11-16                                 FriendFinder
# ...               ...                                          ...
# 7231       2014-09-23                  Six Continents Hotels, Inc.
# 7354       2014-04-07                                     FujiFilm
# 7787       2018-01-10                          St. Vincent Warrick
# 7235       2014-09-18                            CareCentrix, Inc.
# 7302       2014-06-09                                 Intuit, Inc.
#
#            State Type of breach Type of organization  Total Records  \
# 5066  California           HACK                  BSO     3000000000
# 5171      Oregon           DISC                  BSO     1370000000
# 4207   Wisconsin           HACK                  BSO     1000000000
# 4944  California           HACK                  BSO      500000000
# 5029  California           HACK                  BSO      412000000
# ...          ...            ...                  ...            ...
# 7231    Maryland           INSD                  MED              1
# 7354    New York           HACK                  MED              1
# 7787     Indiana           DISC                  MED              1
# 7235    Maryland           INSD                  MED              1
# 7302    Maryland           HACK                  MED              1
#
#                                 Description of incident  \
# 5066  "Yahoo Inc (YHOO.O) warned on Wednesday that i...
# 5171  "One of the world's allegedly most prolific sp...
# 4207  "A gang of Russian hackers has amassed over 1 ...
# 4944  "Yahoo is poised to confirm a massive data bre...
# 5029  "A hack against popular adult dating and enter...
# ...                                                 ...
# 7231  name, payment card info\nLocation of breached ...
# 7354  email system accessed without authorization\nL...
# 7787  St. Vincent learned of an inadvertent disclosu...
# 7235  name, address, dob, ssn, health plan numbers\n...
# 7302  address, name, ssn FEINs,and bank account numb...
#
#              Information Source  \
# 5066                      Media
# 5171                      Media
# 4207                      Media
# 4944                      Media
# 5029                      Media
# ...                         ...
# 7231  Maryland Attorney General
# 7354  Maryland Attorney General
# 7787                        NaN
# 7235  Maryland Attorney General
# 7302  Maryland Attorney General
#
#                                              Source URL  Year of Breach  \
# 5066                                                NaN            2016
# 5171                                                NaN            2017
# 4207                                                NaN            2014
# 4944                                                NaN            2016
# 5029                                                NaN            2016
# ...                                                 ...             ...
# 7231  http://www.marylandattorneygeneral.gov/Pages/I...            2014
# 7354  http://www.marylandattorneygeneral.gov/Pages/I...            2014
# 7787                                                NaN            2017
# 7235  http://www.marylandattorneygeneral.gov/Pages/I...            2014
# 7302  http://www.marylandattorneygeneral.gov/Pages/I...            2014
#
#        Latitude   Longitude breach_type_gA breach_type_gB breach_type_gC  \
# 5066  37.368830 -122.036350         Hacker       Outsider         Online
# 5171  45.520842 -122.680344         Others        Insider         Others
# 4207  41.899183  -87.946671         Hacker       Outsider         Online
# 4944  37.368830 -122.036350         Hacker       Outsider         Online
# 5029  37.407315 -122.017311         Hacker       Outsider         Online
# ...         ...         ...            ...            ...            ...
# 7231  40.760537  -73.978890         Others        Insider         Others
# 7354  39.501681  -76.979392         Hacker       Outsider         Online
# 7787  38.973639  -92.743242         Others        Insider         Others
# 7235  40.760537  -73.978890         Others        Insider         Others
# 7302  40.760537  -73.978890         Hacker       Outsider         Online
#
#      breach_type_gD   region_A   region_B age_of_Law        org_group
# 5066        Network       West       West         16  non_F_regulated
# 5171        Network       West       West         12  non_F_regulated
# 4207        Network    Midwest    Midwest         13  non_F_regulated
# 4944        Network       West       West         16  non_F_regulated
# 5029        Network       West       West         16  non_F_regulated
# ...             ...        ...        ...        ...              ...
# 7231         Others      South  Northeast         11      F_regulated
# 7354        Network  Northeast  Northeast         14      F_regulated
# 7787        Network    Midwest    Midwest         13      F_regulated
# 7235         Others      South  Northeast         11      F_regulated
# 7302        Network      South  Northeast         11      F_regulated
#
# [5498 rows x 20 columns]

# %%
# create variable 'records_group'
df['records_group'] = 'Others'
df.loc[5066, 'records_group'] = 'Extraordinary'
df.loc[5171, 'records_group'] = 'Extraordinary'
df.loc[4207, 'records_group'] = 'Extraordinary'
df.head()
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach  ...   Longitude  breach_type_gA breach_type_gB  \
# 0        NaN            2009  ...  -85.715792          Others        Insider
# 1        NaN            2009  ...  -84.552436          Others          Mixed
# 2        NaN            2009  ...  -81.022833          Others          Mixed
# 3        NaN            2009  ...  -73.035663          Others        Insider
# 4        NaN            2009  ... -104.821363          Others          Mixed
#
#   breach_type_gC breach_type_gD   region_A   region_B age_of_Law    org_group  \
# 0         Others        Network      South  Southeast          0  F_regulated
# 1        Offline          Local      South  Southeast         14  F_regulated
# 2        Offline          Local      South  Southeast         14  F_regulated
# 3         Others        Network  Northeast  Northeast         14  F_regulated
# 4        Offline          Local       West       West         13  F_regulated
#
#   records_group
# 0        Others
# 1        Others
# 2        Others
# 3        Others
# 4        Others
#
# [5 rows x 21 columns]

# %%
df.records_group.value_counts()
# Out:
# Others           5495
# Extraordinary       3
# Name: records_group, dtype: int64

# %%
df[df.records_group != 'Others']
# Out:
#      Date Made Public                                      Company  \
# 4207       2014-08-05  Russian hacking discovered by Hold Security
# 5066       2016-12-14                                        Yahoo
# 5171       2017-03-08                             River City Media
#
#            State Type of breach Type of organization  Total Records  \
# 4207   Wisconsin           HACK                  BSO     1000000000
# 5066  California           HACK                  BSO     3000000000
# 5171      Oregon           DISC                  BSO     1370000000
#
#                                 Description of incident Information Source  \
# 4207  "A gang of Russian hackers has amassed over 1 ...              Media
# 5066  "Yahoo Inc (YHOO.O) warned on Wednesday that i...              Media
# 5171  "One of the world's allegedly most prolific sp...              Media
#
#      Source URL  Year of Breach  ...   Longitude  breach_type_gA  \
# 4207        NaN            2014  ...  -87.946671          Hacker
# 5066        NaN            2016  ... -122.036350          Hacker
# 5171        NaN            2017  ... -122.680344          Others
#
#      breach_type_gB breach_type_gC breach_type_gD region_A region_B  \
# 4207       Outsider         Online        Network  Midwest  Midwest
# 5066       Outsider         Online        Network     West     West
# 5171        Insider         Others        Network     West     West
#
#      age_of_Law        org_group  records_group
# 4207         13  non_F_regulated  Extraordinary
# 5066         16  non_F_regulated  Extraordinary
# 5171         12  non_F_regulated  Extraordinary
#
# [3 rows x 21 columns]

# %%
# description of 'Total Records' for the 'Others' group
df[df.records_group == 'Others']['Total Records'].describe()
# Out:
# count    5.495000e+03
# mean     8.315699e+05
# std      1.268289e+07
# min      1.000000e+00
# 25%      6.580000e+02
# 50%      2.088000e+03
# 75%      1.050050e+04
# max      5.000000e+08
# Name: Total Records, dtype: float64

# %% [markdown]
# #### records_index

# %%
# get the mean of Total Records for records_group Extraordinary and Others.
extra_mean = df.groupby('records_group')['Total Records'].mean()['Extraordinary']
others_mean = df.groupby('records_group')['Total Records'].mean()['Others']

# %%
# Create a new variable named records_index, the values of records_index would be 
# total records divided by mean
df['records_index'] = df['Total Records'] / others_mean
df.loc[4207, 'records_index'] = (df['Total Records'][4207] / extra_mean)
df.loc[5066, 'records_index'] = (df['Total Records'][5066] / extra_mean)
df.loc[5171, 'records_index'] = (df['Total Records'][5171] / extra_mean)

# %% [markdown]
# #### severity_index1, severity_index2, severity_index3

# %%
# adjust to width to show all the columns
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude breach_type_gA  \
# 0        NaN            2009  37.988399  -85.715792         Others
# 1        NaN            2009  35.933964  -84.552436         Others
# 2        NaN            2009  29.210815  -81.022833         Others
# 3        NaN            2009  40.866487  -73.035663         Others
# 4        NaN            2009  38.833882 -104.821363         Others
#
#   breach_type_gB breach_type_gC breach_type_gD   region_A   region_B  \
# 0        Insider         Others        Network      South  Southeast
# 1          Mixed        Offline          Local      South  Southeast
# 2          Mixed        Offline          Local      South  Southeast
# 3        Insider         Others        Network  Northeast  Northeast
# 4          Mixed        Offline          Local       West       West
#
#   age_of_Law    org_group records_group  records_index
# 0          0  F_regulated        Others       0.000813
# 1         14  F_regulated        Others       0.017777
# 2         14  F_regulated        Others       0.039684
# 3         14  F_regulated        Others       0.000361
# 4         13  F_regulated        Others       0.000210

# %%
# use a sigmoid function to turn the total records into scale between 0 and 10
df['records_scale'] = 10/(1 + np.exp(-df['Total Records'])) 
df['records_scale'].value_counts()
# Out:
# 10.000000    5170
# 7.310586       43
# 10.000000      22
# 8.807971       21
# 9.999939       16
# 10.000000      16
# 9.999999       14
# 9.999833       14
# 9.999997       12
# 9.999546       12
# 9.999977       11
# 10.000000      11
# 9.525741       10
# 10.000000       9
# 9.933071        9
# 9.820138        9
# 9.996646        8
# 10.000000       8
# 10.000000       8
# 10.000000       7
# 10.000000       6
# 9.999992        6
# 10.000000       6
# 9.975274        5
# 10.000000       5
# 10.000000       4
# 10.000000       4
# 10.000000       4
# 9.990889        4
# 10.000000       4
# 10.000000       4
# 10.000000       3
# 9.998766        3
# 10.000000       3
# 10.000000       3
# 10.000000       2
# 10.000000       2
# Name: records_scale, dtype: int64

# %%
# create a new variable type_scale to meature the cost by breach type
type_wt_dict = {'DISC': 1, 'PORT': 7, 'PHYS': 7, 'UNKN': 5, 'INSD': 7, 'HACK': 10, 'STAT': 7, 'CARD': 10}
df['type_scale'] = df['Type of breach'].map(type_wt_dict)
df.head(5)
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude breach_type_gA  \
# 0        NaN            2009  37.988399  -85.715792         Others
# 1        NaN            2009  35.933964  -84.552436         Others
# 2        NaN            2009  29.210815  -81.022833         Others
# 3        NaN            2009  40.866487  -73.035663         Others
# 4        NaN            2009  38.833882 -104.821363         Others
#
#   breach_type_gB breach_type_gC breach_type_gD   region_A   region_B  \
# 0        Insider         Others        Network      South  Southeast
# 1          Mixed        Offline          Local      South  Southeast
# 2          Mixed        Offline          Local      South  Southeast
# 3        Insider         Others        Network  Northeast  Northeast
# 4          Mixed        Offline          Local       West       West
#
#   age_of_Law    org_group records_group  records_index  records_scale  \
# 0          0  F_regulated        Others       0.000813           10.0
# 1         14  F_regulated        Others       0.017777           10.0
# 2         14  F_regulated        Others       0.039684           10.0
# 3         14  F_regulated        Others       0.000361           10.0
# 4         13  F_regulated        Others       0.000210           10.0
#
#    type_scale
# 0           1
# 1           7
# 2           7
# 3           1
# 4           7

# %%
# create a new variable org_scale to meature the cost by organization
org_wt_dict = {'EDU': 8, 'MED': 10, 'BSF': 9, 'GOV': 1, 'BSO': 6, 'BSR': 3, 'NGO': 1, 'UNKN': 5}
df['org_scale'] = df['Type of organization'].map(org_wt_dict)
df.head(5)
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude breach_type_gA  \
# 0        NaN            2009  37.988399  -85.715792         Others
# 1        NaN            2009  35.933964  -84.552436         Others
# 2        NaN            2009  29.210815  -81.022833         Others
# 3        NaN            2009  40.866487  -73.035663         Others
# 4        NaN            2009  38.833882 -104.821363         Others
#
#   breach_type_gB breach_type_gC breach_type_gD   region_A   region_B  \
# 0        Insider         Others        Network      South  Southeast
# 1          Mixed        Offline          Local      South  Southeast
# 2          Mixed        Offline          Local      South  Southeast
# 3        Insider         Others        Network  Northeast  Northeast
# 4          Mixed        Offline          Local       West       West
#
#   age_of_Law    org_group records_group  records_index  records_scale  \
# 0          0  F_regulated        Others       0.000813           10.0
# 1         14  F_regulated        Others       0.017777           10.0
# 2         14  F_regulated        Others       0.039684           10.0
# 3         14  F_regulated        Others       0.000361           10.0
# 4         13  F_regulated        Others       0.000210           10.0
#
#    type_scale  org_scale
# 0           1          8
# 1           7          8
# 2           7         10
# 3           1          8
# 4           7         10

# %%
# create severity_index1, severity_index2 and severity_index3
df['severity_index1'] = df['records_scale'] + df['type_scale']
df['severity_index2'] = df['records_scale'] + df['org_scale']
df['severity_index3'] = df['records_scale'] + df['org_scale'] + df['type_scale']
df.head()
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude breach_type_gA  \
# 0        NaN            2009  37.988399  -85.715792         Others
# 1        NaN            2009  35.933964  -84.552436         Others
# 2        NaN            2009  29.210815  -81.022833         Others
# 3        NaN            2009  40.866487  -73.035663         Others
# 4        NaN            2009  38.833882 -104.821363         Others
#
#   breach_type_gB breach_type_gC breach_type_gD   region_A   region_B  \
# 0        Insider         Others        Network      South  Southeast
# 1          Mixed        Offline          Local      South  Southeast
# 2          Mixed        Offline          Local      South  Southeast
# 3        Insider         Others        Network  Northeast  Northeast
# 4          Mixed        Offline          Local       West       West
#
#   age_of_Law    org_group records_group  records_index  records_scale  \
# 0          0  F_regulated        Others       0.000813           10.0
# 1         14  F_regulated        Others       0.017777           10.0
# 2         14  F_regulated        Others       0.039684           10.0
# 3         14  F_regulated        Others       0.000361           10.0
# 4         13  F_regulated        Others       0.000210           10.0
#
#    type_scale  org_scale  severity_index1  severity_index2  severity_index3
# 0           1          8             11.0             18.0             19.0
# 1           7          8             17.0             18.0             25.0
# 2           7         10             17.0             20.0             27.0
# 3           1          8             11.0             18.0             19.0
# 4           7         10             17.0             20.0             27.0

# %% [markdown]
# #### severity_index4, severity_index5

# %%
# create severity_index4 which is the mean of the three scales
df['severity_index4'] = df[['records_scale','org_scale', 'type_scale']].mean(axis=1)

# %%
# create severity_index5 which is the variance of the three scales
df['severity_index5'] = df[['records_scale','org_scale', 'type_scale']].var(axis=1)
df.head()
# Out:
#   Date Made Public                         Company      State Type of breach  \
# 0       2009-10-21   Bullitt County Public Schools   Kentucky           DISC
# 1       2009-10-21  Roane State Community College   Tennessee           PORT
# 2       2009-10-15                  Halifax Health    Florida           PORT
# 3       2009-10-04       Suffolk Community College   New York           DISC
# 4       2009-09-28                Penrose Hospital   Colorado           PHYS
#
#   Type of organization  Total Records  \
# 0                  EDU            676
# 1                  EDU          14783
# 2                  MED          33000
# 3                  EDU            300
# 4                  MED            175
#
#                              Description of incident Information Source  \
# 0  A Bullitt County Public Schools \n            ...        Dataloss DB
# 1  Roane State Community College \n            ha...        Dataloss DB
# 2  A laptop computer from a Halifax \n           ...        Dataloss DB
# 3  Suffolk Community College has \n            ag...        Dataloss DB
# 4  Officials at Penrose Hospital              bel...        Dataloss DB
#
#   Source URL  Year of Breach   Latitude   Longitude breach_type_gA  \
# 0        NaN            2009  37.988399  -85.715792         Others
# 1        NaN            2009  35.933964  -84.552436         Others
# 2        NaN            2009  29.210815  -81.022833         Others
# 3        NaN            2009  40.866487  -73.035663         Others
# 4        NaN            2009  38.833882 -104.821363         Others
#
#   breach_type_gB breach_type_gC breach_type_gD   region_A   region_B  \
# 0        Insider         Others        Network      South  Southeast
# 1          Mixed        Offline          Local      South  Southeast
# 2          Mixed        Offline          Local      South  Southeast
# 3        Insider         Others        Network  Northeast  Northeast
# 4          Mixed        Offline          Local       West       West
#
#   age_of_Law    org_group records_group  records_index  records_scale  \
# 0          0  F_regulated        Others       0.000813           10.0
# 1         14  F_regulated        Others       0.017777           10.0
# 2         14  F_regulated        Others       0.039684           10.0
# 3         14  F_regulated        Others       0.000361           10.0
# 4         13  F_regulated        Others       0.000210           10.0
#
#    type_scale  org_scale  severity_index1  severity_index2  severity_index3  \
# 0           1          8             11.0             18.0             19.0
# 1           7          8             17.0             18.0             25.0
# 2           7         10             17.0             20.0             27.0
# 3           1          8             11.0             18.0             19.0
# 4           7         10             17.0             20.0             27.0
#
#    severity_index4  severity_index5
# 0         6.333333        22.333333
# 1         8.333333         2.333333
# 2         9.000000         3.000000
# 3         6.333333        22.333333
# 4         9.000000         3.000000

# %% [markdown]
# ### Saving data

# %%
#save data to csv file 
df.to_csv('data/data_breach.csv',index=False)
